# %% [markdown]
# # Application programming Interface

# %% [markdown]
# 1. front End --> web app , android device , website

# %% [markdown]
# 2. BackEnd --> Datbase , sensor(live) etc

# %%
import requests

# %%
page = requests.get("https://images.pexels.com/photos/67636/rose-blue-flower-rose-blooms-67636.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# C:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# C:\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
page.status_code

# %%
page.content[:100]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
f = open("img.jpg","wb")
f.close()
img = plt.imread("img.jpg")
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
page = requests.get("https://img.etimg.com/thumb/msid-69884110,width-643,imgsize-295694,resizemode-4/doode.jpg")

# %%
page.status_code
# Out:
# 200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
f = open("img.jpg","wb")
f.write(page.content)
f.close()
img = plt.imread("img.jpg")
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
google_token = "AIzaSyBy6pJs4DApRua7iNF0T4DNSksHLoshyf8"

# %%
import requests
query = "jaipurrajasthan"
url =  f"https://maps.googleapis.com/maps/api/place/details/json?{query}={google_token}"
page = requests.get(url)
if page.status_code == 200:
    data = page.json()
else:
    print("invlid search")

# %%
data
# Out:
# {'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account',
#  'html_attributions': [],
#  'status': 'REQUEST_DENIED'}
